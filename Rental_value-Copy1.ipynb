# %%
#Rental Value

# %%
import pandas as pd
import hvplot.pandas
from pathlib import Path
import numpy as np
import holoviews as hv

# %%
rental_data_path = Path('/Users/yuvrajkabra/Documents/Bootcamp/Project 1/Real_Estate_Project/Rental_data.csv')
rental_data_df = pd.read_csv(rental_data_path).dropna()

# %%
rental_data = rental_data_df.drop(columns=["RegionID", "SizeRank"])
rental_data
# Out:
#                              RegionName  2014-01  2014-02  2014-03  2014-04  \
# 0                         United States   1283.0     1294   1295.0     1302
# 1                          New York, NY   2306.0     2335   2342.0     2348
# 2    Los Angeles-Long Beach-Anaheim, CA   1815.0     1846   1833.0     1842
# 3                           Chicago, IL   1464.0     1477   1478.0     1483
# 4                 Dallas-Fort Worth, TX   1105.0     1130   1136.0     1152
# ..                                  ...      ...      ...      ...      ...
# 104                    Fort Collins, CO   1237.0     1270   1260.0     1267
# 105                         Boulder, CO   1456.0     1489   1456.0     1443
# 106                 College Station, TX    984.0     1026   1005.0     1017
# 107                     Gainesville, GA    883.0      922    936.0      928
# 108                    Sierra Vista, AZ    781.0      822    804.0      797
#
#      2014-05  2014-06  2014-07  2014-08  2014-09  ...  2021-09  2021-10  \
# 0       1315     1325     1334     1339     1341  ...     1843     1861
# 1       2382     2400     2418     2426     2429  ...     2799     2826
# 2       1865     1885     1903     1918     1927  ...     2708     2735
# 3       1499     1514     1522     1525     1519  ...     1809     1813
# 4       1147     1150     1155     1157     1161  ...     1667     1681
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 104     1273     1275     1285     1281     1314  ...     1732     1757
# 105     1457     1492     1505     1514     1535  ...     2067     2073
# 106     1021     1031     1034     1038     1059  ...     1237     1256
# 107      930      934      926      933      925  ...     1533     1532
# 108      802      810      809      793      795  ...     1118     1175
#
#      2021-11  2021-12  2022-01  2022-02  2022-03  2022-04  2022-05  2022-06
# 0       1878     1895     1901     1925     1942     1965     1991     2007
# 1       2852     2884     2917     2970     3019     3072     3135     3186
# 2       2759     2781     2801     2834     2863     2900     2935     2951
# 3       1818     1832     1846     1860     1883     1907     1931     1947
# 4       1700     1710     1719     1735     1744     1771     1802     1825
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 104     1757     1776     1773     1797     1811     1825     1855     1874
# 105     2080     2104     2131     2147     2185     2206     2219     2221
# 106     1296     1310     1318     1333     1346     1353     1354     1356
# 107     1561     1583     1600     1605     1615     1606     1627     1652
# 108     1169     1152     1066     1108     1213     1237     1224     1171
#
# [101 rows x 103 columns]

# %%
rental_data_df['State'] = rental_data_df['RegionName'].str[-2:]

# %%
rental_data_df
# Out:
#      RegionID                          RegionName  SizeRank  2014-01  2014-02  \
# 0      102001                       United States         0   1283.0     1294
# 1      394913                        New York, NY         1   2306.0     2335
# 2      753899  Los Angeles-Long Beach-Anaheim, CA         2   1815.0     1846
# 3      394463                         Chicago, IL         3   1464.0     1477
# 4      394514               Dallas-Fort Worth, TX         4   1105.0     1130
# ..        ...                                 ...       ...      ...      ...
# 104    394602                    Fort Collins, CO       159   1237.0     1270
# 105    394405                         Boulder, CO       162   1456.0     1489
# 106    394483                 College Station, TX       192    984.0     1026
# 107    394623                     Gainesville, GA       229    883.0      922
# 108    395098                    Sierra Vista, AZ       309    781.0      822
#
#      2014-03  2014-04  2014-05  2014-06  2014-07  ...  2021-10  2021-11  \
# 0     1295.0     1302     1315     1325     1334  ...     1861     1878
# 1     2342.0     2348     2382     2400     2418  ...     2826     2852
# 2     1833.0     1842     1865     1885     1903  ...     2735     2759
# 3     1478.0     1483     1499     1514     1522  ...     1813     1818
# 4     1136.0     1152     1147     1150     1155  ...     1681     1700
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 104   1260.0     1267     1273     1275     1285  ...     1757     1757
# 105   1456.0     1443     1457     1492     1505  ...     2073     2080
# 106   1005.0     1017     1021     1031     1034  ...     1256     1296
# 107    936.0      928      930      934      926  ...     1532     1561
# 108    804.0      797      802      810      809  ...     1175     1169
#
#      2021-12  2022-01  2022-02  2022-03  2022-04  2022-05  2022-06  State
# 0       1895     1901     1925     1942     1965     1991     2007     es
# 1       2884     2917     2970     3019     3072     3135     3186     NY
# 2       2781     2801     2834     2863     2900     2935     2951     CA
# 3       1832     1846     1860     1883     1907     1931     1947     IL
# 4       1710     1719     1735     1744     1771     1802     1825     TX
# ..       ...      ...      ...      ...      ...      ...      ...    ...
# 104     1776     1773     1797     1811     1825     1855     1874     CO
# 105     2104     2131     2147     2185     2206     2219     2221     CO
# 106     1310     1318     1333     1346     1353     1354     1356     TX
# 107     1583     1600     1605     1615     1606     1627     1652     GA
# 108     1152     1066     1108     1213     1237     1224     1171     AZ
#
# [101 rows x 106 columns]

# %%
rental_data_df.replace(to_replace=["es"], value="US")
# Out:
#      RegionID                          RegionName  SizeRank  2014-01  2014-02  \
# 0      102001                       United States         0   1283.0     1294
# 1      394913                        New York, NY         1   2306.0     2335
# 2      753899  Los Angeles-Long Beach-Anaheim, CA         2   1815.0     1846
# 3      394463                         Chicago, IL         3   1464.0     1477
# 4      394514               Dallas-Fort Worth, TX         4   1105.0     1130
# ..        ...                                 ...       ...      ...      ...
# 104    394602                    Fort Collins, CO       159   1237.0     1270
# 105    394405                         Boulder, CO       162   1456.0     1489
# 106    394483                 College Station, TX       192    984.0     1026
# 107    394623                     Gainesville, GA       229    883.0      922
# 108    395098                    Sierra Vista, AZ       309    781.0      822
#
#      2014-03  2014-04  2014-05  2014-06  2014-07  ...  2021-10  2021-11  \
# 0     1295.0     1302     1315     1325     1334  ...     1861     1878
# 1     2342.0     2348     2382     2400     2418  ...     2826     2852
# 2     1833.0     1842     1865     1885     1903  ...     2735     2759
# 3     1478.0     1483     1499     1514     1522  ...     1813     1818
# 4     1136.0     1152     1147     1150     1155  ...     1681     1700
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 104   1260.0     1267     1273     1275     1285  ...     1757     1757
# 105   1456.0     1443     1457     1492     1505  ...     2073     2080
# 106   1005.0     1017     1021     1031     1034  ...     1256     1296
# 107    936.0      928      930      934      926  ...     1532     1561
# 108    804.0      797      802      810      809  ...     1175     1169
#
#      2021-12  2022-01  2022-02  2022-03  2022-04  2022-05  2022-06  State
# 0       1895     1901     1925     1942     1965     1991     2007     US
# 1       2884     2917     2970     3019     3072     3135     3186     NY
# 2       2781     2801     2834     2863     2900     2935     2951     CA
# 3       1832     1846     1860     1883     1907     1931     1947     IL
# 4       1710     1719     1735     1744     1771     1802     1825     TX
# ..       ...      ...      ...      ...      ...      ...      ...    ...
# 104     1776     1773     1797     1811     1825     1855     1874     CO
# 105     2104     2131     2147     2185     2206     2219     2221     CO
# 106     1310     1318     1333     1346     1353     1354     1356     TX
# 107     1583     1600     1605     1615     1606     1627     1652     GA
# 108     1152     1066     1108     1213     1237     1224     1171     AZ
#
# [101 rows x 106 columns]

# %%
rental_data_by_state = rental_data_df.groupby("State").mean()
rental_data_by_state.head()
# Out:
#             RegionID    SizeRank      2014-01      2014-02      2014-03  \
# State
# AL     394388.000000   49.000000   942.000000   949.000000   948.000000
# AR     394798.000000   76.000000   859.000000   880.000000   857.000000
# AZ     395080.333333  125.333333   886.666667   909.666667   901.333333
# CA     434793.777778   36.666667  1540.888889  1538.777778  1541.333333
# CO     394505.250000  105.500000  1233.750000  1242.000000  1240.000000
#
#            2014-04      2014-05      2014-06      2014-07      2014-08  ...  \
# State                                                                   ...
# AL      946.000000   946.000000   954.000000   956.000000   967.000000  ...
# AR      866.000000   866.000000   869.000000   874.000000   880.000000  ...
# AZ      899.666667   905.333333   911.000000   912.000000   907.333333  ...
# CA     1551.111111  1572.111111  1587.777778  1599.777778  1610.222222  ...
# CO     1245.250000  1258.750000  1279.000000  1290.250000  1296.000000  ...
#
#            2021-09      2021-10      2021-11      2021-12      2022-01  \
# State
# AL     1253.000000  1265.000000  1285.000000  1289.000000  1293.000000
# AR     1123.000000  1118.000000  1129.000000  1135.000000  1122.000000
# AZ     1476.000000  1513.333333  1523.666667  1525.000000  1500.666667
# CA     2434.111111  2444.666667  2456.444444  2475.333333  2487.777778
# CO     1857.500000  1866.500000  1871.250000  1886.750000  1896.250000
#
#            2022-02      2022-03      2022-04      2022-05      2022-06
# State
# AL     1293.000000  1305.000000  1314.000000  1326.000000  1332.000000
# AR     1130.000000  1137.000000  1137.000000  1152.000000  1167.000000
# AZ     1528.000000  1570.666667  1586.000000  1587.333333  1576.333333
# CA     2514.333333  2539.666667  2567.222222  2598.222222  2606.111111
# CO     1914.000000  1937.500000  1957.250000  1981.000000  1994.500000
#
# [5 rows x 104 columns]

# %%
rental_data_by_state = rental_data_by_state.drop(columns=["RegionID", "SizeRank"])
rental_data_by_state.head()
# Out:
#            2014-01      2014-02      2014-03      2014-04      2014-05  \
# State
# AL      942.000000   949.000000   948.000000   946.000000   946.000000
# AR      859.000000   880.000000   857.000000   866.000000   866.000000
# AZ      886.666667   909.666667   901.333333   899.666667   905.333333
# CA     1540.888889  1538.777778  1541.333333  1551.111111  1572.111111
# CO     1233.750000  1242.000000  1240.000000  1245.250000  1258.750000
#
#            2014-06      2014-07      2014-08      2014-09      2014-10  ...  \
# State                                                                   ...
# AL      954.000000   956.000000   967.000000   965.000000   962.000000  ...
# AR      869.000000   874.000000   880.000000   883.000000   877.000000  ...
# AZ      911.000000   912.000000   907.333333   909.000000   911.000000  ...
# CA     1587.777778  1599.777778  1610.222222  1621.555556  1628.333333  ...
# CO     1279.000000  1290.250000  1296.000000  1312.250000  1316.500000  ...
#
#            2021-09      2021-10      2021-11      2021-12      2022-01  \
# State
# AL     1253.000000  1265.000000  1285.000000  1289.000000  1293.000000
# AR     1123.000000  1118.000000  1129.000000  1135.000000  1122.000000
# AZ     1476.000000  1513.333333  1523.666667  1525.000000  1500.666667
# CA     2434.111111  2444.666667  2456.444444  2475.333333  2487.777778
# CO     1857.500000  1866.500000  1871.250000  1886.750000  1896.250000
#
#            2022-02      2022-03      2022-04      2022-05      2022-06
# State
# AL     1293.000000  1305.000000  1314.000000  1326.000000  1332.000000
# AR     1130.000000  1137.000000  1137.000000  1152.000000  1167.000000
# AZ     1528.000000  1570.666667  1586.000000  1587.333333  1576.333333
# CA     2514.333333  2539.666667  2567.222222  2598.222222  2606.111111
# CO     1914.000000  1937.500000  1957.250000  1981.000000  1994.500000
#
# [5 rows x 102 columns]

# %%
rental_data_by_state = rental_data_by_state.transpose()

# %%
#rental_data.columns = rental_data.iloc[0]
#rental_data = rental_data[1:]
rental_data_by_state.head()
# Out:
# State       AL     AR          AZ           CA       CO           CT      DC  \
# 2014-01  942.0  859.0  886.666667  1540.888889  1233.75  1452.000000  1778.0
# 2014-02  949.0  880.0  909.666667  1538.777778  1242.00  1459.333333  1819.0
# 2014-03  948.0  857.0  901.333333  1541.333333  1240.00  1468.333333  1807.0
# 2014-04  946.0  866.0  899.666667  1551.111111  1245.25  1479.000000  1806.0
# 2014-05  946.0  866.0  905.333333  1572.111111  1258.75  1501.000000  1819.0
#
# State        FL          GA      HI  ...      PA      RI      SC       TN  \
# 2014-01  1112.5  947.666667  1956.0  ...  1058.0  1093.0  1044.0   971.00
# 2014-02  1117.7  976.000000  1993.0  ...  1074.2  1176.0  1097.0   991.25
# 2014-03  1120.2  975.666667  1987.0  ...  1068.8  1168.0  1084.5   993.75
# 2014-04  1125.8  971.666667  1978.0  ...  1073.0  1158.0  1099.5  1000.00
# 2014-05  1134.2  973.666667  2024.0  ...  1081.0  1157.0  1091.0   995.50
#
# State             TX          UT      VA      WA      WI      es
# 2014-01  1042.142857  956.666667  1153.0  1149.0  1060.0  1283.0
# 2014-02  1059.428571  998.666667  1170.0  1206.0  1032.0  1294.0
# 2014-03  1055.714286  986.666667  1167.0  1184.5  1034.0  1295.0
# 2014-04  1065.142857  988.333333  1169.0  1173.5  1030.0  1302.0
# 2014-05  1072.714286  999.333333  1175.0  1189.0  1034.0  1315.0
#
# [5 rows x 40 columns]

# %%
#print(rental_data.columns)

# %%
#rental_data['RegionName'] = rental_data['RegionName'].drop_duplicates(keep='first')

# %%
#rental_data = rental_data.dropna()

# %%
#rental_data

# %%
#rental_data = rental_data.transpose()

# %%
#rental_data.columns = rental_data.iloc[0]
#rental_data = rental_data[1:]
#rental_data.head()

# %%
#print(rental_data.columns)

# %%
rental_data_by_state.hvplot(
    ylabel='Rental Income',
    title="Average US Rental Income By State ",
    ).opts(yformatter='%.0f')
# Out:
# :NdOverlay   [State]
#    :Curve   [index]   (value)

# %%
rental_each_state = rental_data_by_state.hvplot(
    ylabel='Rental Income',
    title="Average US Rental Income By State ",
    ).opts(yformatter='%.0f')
individual_plots = hv.HoloMap(rental_each_state).opts(yformatter='%.0f')
individual_plots
# Out:
# :HoloMap   [State]
#    :Curve   [index]   (value)

# %%
#investable_states = rental_data.loc['NY', 'CA']
print(rental_data_by_state.columns)
# Out:
# Index(['AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'FL', 'GA', 'HI', 'IA', 'ID',
#        'IL', 'IN', 'KY', 'LA', 'MA', 'MD', 'MI', 'MN', 'MO', 'MS', 'NC', 'NE',
#        'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'TN', 'TX', 'UT',
#        'VA', 'WA', 'WI', 'es'],
#       dtype='object', name='State')

# %%
investable_states = rental_data_by_state.loc['CA']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/cc/_2prfvkj35zgpxt8t6b_9llc0000gn/T/ipykernel_79712/3892269481.py in <module>
# ----> 1 investable_states = rental_data_by_state.loc['CA']
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'CA'
